# %% [markdown]
# # SQL Practice Notebook
# ---
#
# ### Introduction:
#
# "`SQL` (**S**tructured **Q**uery **L**anguage) is a programming language designed for managing data in a relational [database](https://en.wikipedia.org/wiki/Database). It's been around since the 1970s and is the most common method of accessing data in databases today. SQL has a variety of functions that allow its users to read, manipulate, and change data. Though SQL is commonly used by engineers in software development, it's also popular with data analysts for a few reasons:
#
# - It's **semantically easy** to understand and learn.
# - Because it can be used to **access large amounts of data directly where it's stored**, analysts don't have to copy data into other applications.
# - Compared to spreadsheet tools, data analysis done in **SQL is easy to audit and replicate**. For analysts, this means no more looking for the cell with the typo in the formula.
#
# SQL is great for performing the types of aggregations that you might normally do in an `Excel pivot table—sums`, `ccounts`, `minimums and maximums`, etc.—but over much **larger datasets and on multiple tables at the same time**." [[8]](https://mode.com/sql-tutorial/introduction-to-sql/)
#
# ### Objectives:
#
#  The main objective of this notebook is practicing basic SQL querying using sqlite3 python library.
#
# ### Dataset:
#
# I will be using the World Development Indicator (WDI) dataset and we'll be querying about a subset of world countries; I chose the Sub-Saharan Africa region.
#
# ### Inspiration:
#
# This notebook is hugely inspired by [the notebook (ref.1)](https://www.kaggle.com/code/jonaspalucibarbosa/wdi-brazil-unemployment-using-sql-for-analysis) of Jonas Paluci Barbosa who made a similar notebook using the same dataset.

# %%
import sqlite3
import numpy as np 
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
PATH_TO_SQLITE_MASTER = '../input/world-development-indicators/database.sqlite'

# %% [markdown]
# ## 1. Explore the database
# ### 1.1 List all the tables in the database.
#
# We see from the right hand side of the notebook all the tables in the sqlite database and this step may not be necessary. Nevertheless, as this is a practice notebook we will list them anyway. We will note that there are 6 tables.

# %%
## (ref.2) https://www.geeksforgeeks.org/how-to-list-tables-using-sqlite3-in-python/
try:    
    connect = sqlite3.connect(PATH_TO_SQLITE_MASTER)
    print("Connected to SQLite")
    
    sql_query = """
    SELECT name 
    FROM sqlite_master
    WHERE type='table';
    """
    cursor = connect.cursor()
    cursor.execute(sql_query)
       
    print("List of tables\n")
    print(cursor.fetchall())
    
    
except sqlite3.Error as error:
    
    print("Failed to execute the above query", error)
# Out:
# Failed to execute the above query unable to open database file

# %% [markdown]
# Alternatively we can also print a dataframe of the tabels containg all information as shown below.

# %%
df_tables =  pd.read_sql("""
    SELECT * 
    FROM sqlite_master
    WHERE type='table';
    """,
            con = connect            
)
df_tables

# %% [markdown]
# ### 1.2 The tables
# #### 1.2.1 Country
#
# Column-wise this is the biggest table with 31 columns and has entries for 247 countries. This table contains several information about the data collected for all countries.

# %%
df_country =  pd.read_sql("""

SELECT *
FROM Country
""",
            con = connect            
)
display(df_country.head(3))
df_country.shape
# Out:
#   CountryCode    ShortName    TableName  \
# 0         AFG  Afghanistan  Afghanistan
# 1         ALB      Albania      Albania
# 2         DZA      Algeria      Algeria
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1
# 2
#
#                        Region          IncomeGroup Wb2Code  ...  \
# 0                  South Asia           Low income      AF  ...
# 1       Europe & Central Asia  Upper middle income      AL  ...
# 2  Middle East & North Africa  Upper middle income      DZ  ...
#
#        GovernmentAccountingConcept              ImfDataDisseminationStandard  \
# 0  Consolidated central government  General Data Dissemination System (GDDS)
# 1     Budgetary central government  General Data Dissemination System (GDDS)
# 2     Budgetary central government  General Data Dissemination System (GDDS)
#
#   LatestPopulationCensus                              LatestHouseholdSurvey  \
# 0                   1979  Multiple Indicator Cluster Survey (MICS), 2010/11
# 1                   2011       Demographic and Health Survey (DHS), 2008/09
# 2                   2008     Multiple Indicator Cluster Survey (MICS), 2012
#
#           SourceOfMostRecentIncomeAndExpenditureData  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 1995
#
#   VitalRegistrationComplete LatestAgriculturalCensus LatestIndustrialData  \
# 0                                            2013/14
# 1                       Yes                     2012                 2011
# 2                                                                    2010
#
#   LatestTradeData LatestWaterWithdrawalData
# 0            2013                      2000
# 1            2013                      2006
# 2            2013                      2001
#
# [3 rows x 31 columns]
# (247, 31)

# %%
df_sub_saharan_africa = df_country[df_country['Region'] == 'Sub-Saharan Africa']
SSA = df_sub_saharan_africa.ShortName.tolist()
display('The Sub-Saharan Africa has {} countries' .format(len(SSA)))

SSA[::5]
# Out:
# 'The Sub-Saharan Africa has 48 countries'
# ['Angola',
#  'Cabo Verde',
#  'Congo',
#  'Ethiopia',
#  'Kenya',
#  'Mali',
#  'Niger',
#  'Seychelles',
#  'Sudan',
#  'Uganda']

# %% [markdown]
# #### 1.2.2 CountryNotes
#
# This table has 4857 rows and 3 columns; Countrycode, Seriescode and Descriptions.

# %%
df_country_notes =  pd.read_sql("""

SELECT *
FROM CountryNotes 
""",
            con = connect            
)
df_country_notes.head(3)
# Out:
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...
# 1               Sources: UN Energy Statistics (2014)
# 2               Sources: UN Energy Statistics (2014)

# %% [markdown]
# #### 1.2.3 Footnotes
#
# This table contains 532415 rows and 4 columns (Countrycode, Seriescode, Year and Description).

# %%
df_footnotes =  pd.read_sql(""" 
SELECT * 
FROM Footnotes 
""", 
                            con = connect)
df_footnotes.tail(3)
# Out:
#        Countrycode         Seriescode    Year  \
# 532412         ZWE  TX.VAL.MRCH.XD.WD  YR2008
# 532413         ZWE  TX.VAL.MRCH.XD.WD  YR2009
# 532414         ZWE  TX.VAL.MRCH.XD.WD  YR2010
#
#                                               Description
# 532412  Source: UNCTAD Handbook of Statistics and data...
# 532413  Source: UNCTAD Handbook of Statistics and data...
# 532414  Source: UNCTAD Handbook of Statistics and data...

# %% [markdown]
# #### 1.2.4. Indicators
#
# Row-wise this is the largest table with 5656458 rows and 6 columns. This is in a way the `"data table"` of the WDI dataset. It contains the reported values (measured/modelled) of all indicators for all countries in the countries-list for the years 1960 to 2014.

# %%
df_indicators =  pd.read_sql("""

SELECT *
FROM Indicators
""",
            con = connect            
)
df_indicators.head(3)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
#
#     IndicatorCode  Year       Value
# 0     SP.ADO.TFRT  1960  133.560907
# 1     SP.POP.DPND  1960   87.797601
# 2  SP.POP.DPND.OL  1960    6.634579

# %%
df_last =  pd.read_sql("""
SELECT MAX(Year) AS LatestYear
FROM Indicators
""",
            con = connect            
)

df_start =  pd.read_sql("""
SELECT MIN(Year) AS EarliestYear
FROM Indicators
""",
            con = connect            
)
pd.concat([df_start, df_last], axis=1)
# Out:
#    EarliestYear  LatestYear
# 0          1960        2015

# %% [markdown]
# #### 1.2.5. Series
#
# This table has 1345 rows and 20 columns.

# %%
df_series =  pd.read_sql("""

SELECT *
FROM Series
""",
            con = connect            
)
df_series.head(3)
# Out:
#              SeriesCode                                              Topic  \
# 0        BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1  BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2     BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
#
#                                        IndicatorName ShortDefinition  \
# 0  Foreign direct investment, net (BoP, current US$)
# 1  Foreign direct investment, net inflows (% of GDP)
# 2  Foreign direct investment, net inflows (BoP, c...
#
#                                       LongDefinition UnitOfMeasure  \
# 0  Foreign direct investment are the net inflows ...
# 1  Foreign direct investment are the net inflows ...
# 2  Foreign direct investment refers to direct inv...
#
#   Periodicity BasePeriod OtherNotes AggregationMethod  \
# 0      Annual
# 1      Annual                        Weighted average
# 2      Annual                                     Sum
#
#                             LimitationsAndExceptions NotesFromOriginalSource  \
# 0
# 1  FDI data do not give a complete picture of int...
# 2  FDI data do not give a complete picture of int...
#
#                                      GeneralComments  \
# 0  Note: Data are based on the sixth edition of t...
# 1  Note: Data starting from 2005 are based on the...
# 2  Note: Data starting from 2005 are based on the...
#
#                                               Source  \
# 0  International Monetary Fund, Balance of Paymen...
# 1  International Monetary Fund, International Fin...
# 2  International Monetary Fund, Balance of Paymen...
#
#                     StatisticalConceptAndMethodology  \
# 0
# 1  Data on equity flows are based on balance of p...
# 2  Data on equity flows are based on balance of p...
#
#                                 DevelopmentRelevance RelatedSourceLinks  \
# 0
# 1  Private financial flows - equity and debt - ac...
# 2  Private financial flows - equity and debt - ac...
#
#   OtherWebLinks RelatedIndicators LicenseType
# 0                                        Open
# 1                                        Open
# 2                                        Open

# %% [markdown]
# #### 1.2.6. SeriesNotes
#
# This table has 369 rows and 3 columns, i.e `Seriescode`, `Year`, and `Description`. The table is all about the notes oe descriptions (as given in the `description` column) of each Seriescode for the corresponding year. For example, we can infer from the table that for year 1960 the data for `Health: Reproductive health (Seciecode SP.ADO.TFRT)` was calculated by interpolating using data for 1957 and 1962.

# %%
df_seriesnotes =  pd.read_sql("""

SELECT *
FROM SeriesNotes
""",
            con = connect            
)
df_seriesnotes.head(3)
# Out:
#        Seriescode    Year                                        Description
# 0     SP.ADO.TFRT  YR1960         Interpolated using data for 1957 and 1962.
# 1  SP.DYN.AMRT.FE  YR1960  Interpolated using data for 1957 and 1962, if ...
# 2  SP.DYN.AMRT.MA  YR1960  Interpolated using data for 1957 and 1962, if ...

# %% [markdown]
# ### 2. Query and Analyse
#
# We have now seen that what the tables are and the details of their columns we can query and do futher analysis on a selected topics. Sub-Saharan Africa region is selected as our area of interest and we have selected few questions to ponder. We will limit our focus to topics such as economy,health, natural resources, education and so on. Example question would look like:
#
# 1. Which countries have the most economic growth (measured in GDP) in the last 5 years?
# 2. What is the contribution of natural resources to the countries GDP?
# 3. What is the health expenditure in each country? And their per capita health expenditure?
# 4. Education, Child Labor, etc..

# %%
df_SSA = pd.read_sql("""

SELECT *
FROM Country
WHERE Region = 'Sub-Saharan Africa'
 
""",
            con = connect            
)

print('Number of countries in the Sub-Saharan Africa region is {}'.format(df_SSA.shape[0]))
print('\n')
df_SSA.head(3)
# Out:
# Number of countries in the Sub-Saharan Africa region is 48
#   CountryCode ShortName TableName                     LongName Alpha2Code  \
# 0         AGO    Angola    Angola  People's Republic of Angola         AO
# 1         BEN     Benin     Benin            Republic of Benin         BJ
# 2         BWA  Botswana  Botswana         Republic of Botswana         BW
#
#              CurrencyUnit                                       SpecialNotes  \
# 0          Angolan kwanza  April 2013 database update: Based on IMF data,...
# 1  West African CFA franc
# 2           Botswana pula  Fiscal year end: March 31; reporting period fo...
#
#                Region          IncomeGroup Wb2Code  ...  \
# 0  Sub-Saharan Africa  Upper middle income      AO  ...
# 1  Sub-Saharan Africa           Low income      BJ  ...
# 2  Sub-Saharan Africa  Upper middle income      BW  ...
#
#     GovernmentAccountingConcept              ImfDataDisseminationStandard  \
# 0  Budgetary central government  General Data Dissemination System (GDDS)
# 1  Budgetary central government  General Data Dissemination System (GDDS)
# 2  Budgetary central government  General Data Dissemination System (GDDS)
#
#   LatestPopulationCensus                           LatestHouseholdSurvey  \
# 0                   2014            Malaria Indicator Survey (MIS), 2011
# 1                   2013  Multiple Indicator Cluster Survey (MICS), 2014
# 2                   2011  Multiple Indicator Cluster Survey (MICS), 2000
#
#           SourceOfMostRecentIncomeAndExpenditureData  \
# 0         Integrated household survey (IHS), 2008/09
# 1  Core Welfare Indicator Questionnaire Survey (C...
# 2  Expenditure survey/budget survey (ES/BS), 2009/10
#
#   VitalRegistrationComplete              LatestAgriculturalCensus  \
# 0                                                            2015
# 1                                                         2011/12
# 2                            2011. Population and Housing Census.
#
#   LatestIndustrialData LatestTradeData LatestWaterWithdrawalData
# 0                                                           2005
# 1                                 2013                      2001
# 2                 2011            2013                      2000
#
# [3 rows x 31 columns]

# %% [markdown]
# ### Topics Details
#
# The WDI has several topics covered. These are within the Series table. Let's now print out the list of topics so that we can select the topics of our interest for further analysis.

# %%
topics = pd.read_sql("""
SELECT DISTINCT Topic
FROM Series;
""",
                     connect)

topics.Topic.tolist()
# Out:
# ['Economic Policy & Debt: Balance of payments: Capital & financial account',
#  'Economic Policy & Debt: Balance of payments: Current account: Balances',
#  'Economic Policy & Debt: Balance of payments: Current account: Goods, services & income',
#  'Economic Policy & Debt: Balance of payments: Current account: Transfers',
#  'Economic Policy & Debt: Balance of payments: Reserves & other items',
#  'Economic Policy & Debt: External debt: Amortization',
#  'Economic Policy & Debt: External debt: Arrears, reschedulings, etc.',
#  'Economic Policy & Debt: External debt: Commitments',
#  'Economic Policy & Debt: External debt: Currency composition',
#  'Economic Policy & Debt: External debt: Debt outstanding',
#  'Economic Policy & Debt: External debt: Debt ratios & other items',
#  'Economic Policy & Debt: External debt: Debt service',
#  'Economic Policy & Debt: External debt: Disbursements',
#  'Economic Policy & Debt: External debt: Interest',
#  'Economic Policy & Debt: External debt: Net flows',
#  'Economic Policy & Debt: External debt: Net transfers',
#  'Economic Policy & Debt: External debt: Terms',
#  'Economic Policy & Debt: External debt: Undisbursed debt',
#  'Economic Policy & Debt: National accounts: Adjusted savings & income',
#  'Economic Policy & Debt: National accounts: Atlas GNI & GNI per capita',
#  'Economic Policy & Debt: National accounts: Growth rates',
#  'Economic Policy & Debt: National accounts: Growth rates:',
#  'Economic Policy & Debt: National accounts: Local currency at constant prices: Aggregate indicators',
#  'Economic Policy & Debt: National accounts: Local currency at constant prices: Expenditure on GDP',
#  'Economic Policy & Debt: National accounts: Local currency at constant prices: Other items',
#  'Economic Policy & Debt: National accounts: Local currency at constant prices: Value added',
#  'Economic Policy & Debt: National accounts: Local currency at current prices: Aggregate indicators',
#  'Economic Policy & Debt: National accounts: Local currency at current prices: Expenditure on GDP',
#  'Economic Policy & Debt: National accounts: Local currency at current prices: Value added',
#  'Economic Policy & Debt: National accounts: Shares of GDP & other',
#  'Economic Policy & Debt: National accounts: US$ at constant 2005 prices: Aggregate indicators',
#  'Economic Policy & Debt: National accounts: US$ at constant 2005 prices: Expenditure on GDP',
#  'Economic Policy & Debt: National accounts: US$ at constant 2005 prices: Value added',
#  'Economic Policy & Debt: National accounts: US$ at current prices: Aggregate indicators',
#  'Economic Policy & Debt: National accounts: US$ at current prices: Expenditure on GDP',
#  'Economic Policy & Debt: National accounts: US$ at current prices: Other items',
#  'Economic Policy & Debt: National accounts: US$ at current prices: Value added',
#  'Economic Policy & Debt: Official development assistance',
#  'Economic Policy & Debt: Purchasing power parity',
#  'Education: Efficiency',
#  'Education: Inputs',
#  'Education: Outcomes',
#  'Education: Participation',
#  'Environment: Agricultural production',
#  'Environment: Biodiversity & protected areas',
#  'Environment: Density & urbanization',
#  'Environment: Emissions',
#  'Environment: Energy production & use',
#  'Environment: Freshwater',
#  'Environment: Land use',
#  'Environment: Natural resources contribution to GDP',
#  'Financial Sector: Access',
#  'Financial Sector: Assets',
#  'Financial Sector: Capital markets',
#  'Financial Sector: Exchange rates & prices',
#  'Financial Sector: Interest rates',
#  'Financial Sector: Monetary holdings (liabilities)',
#  'Health: Disease prevention',
#  'Health: Health services',
#  'Health: Mortality',
#  'Health: Nutrition',
#  'Health: Population: Dynamics',
#  'Health: Population: Structure',
#  'Health: Reproductive health',
#  'Health: Risk factors',
#  'Infrastructure: Communications',
#  'Infrastructure: Technology',
#  'Infrastructure: Transportation',
#  'Poverty: Income distribution',
#  'Poverty: Poverty rates',
#  'Poverty: Shared prosperity',
#  'Private Sector & Trade: Business environment',
#  'Private Sector & Trade: Exports',
#  'Private Sector & Trade: Imports',
#  'Private Sector & Trade: Private infrastructure investment',
#  'Private Sector & Trade: Tariffs',
#  'Private Sector & Trade: Total merchandise trade',
#  'Private Sector & Trade: Trade facilitation',
#  'Private Sector & Trade: Trade indexes',
#  'Private Sector & Trade: Travel & tourism',
#  'Public Sector: Conflict & fragility',
#  'Public Sector: Defense & arms trade',
#  'Public Sector: Government finance: Deficit & financing',
#  'Public Sector: Government finance: Expense',
#  'Public Sector: Government finance: Revenue',
#  'Public Sector: Policy & institutions',
#  'Social Protection & Labor: Economic activity',
#  'Social Protection & Labor: Labor force structure',
#  'Social Protection & Labor: Migration',
#  'Social Protection & Labor: Performance',
#  'Social Protection & Labor: Unemployment']

# %% [markdown]
# ### 2.1 GDP Growth (%)
#
# "Gross domestic product (GDP) is the total monetary or market value of all the finished goods and services produced within a country’s borders in a specific time period. As a broad measure of overall domestic production, it functions as a comprehensive scorecard of a given country’s economic health.
#
# "The GDP growth rate compares the year-over-year (or quarterly) change in a country’s economic output to measure how fast an economy is growing. Usually expressed as a percentage rate, this measure is popular for economic policy-makers because GDP growth is thought to be closely connected to key policy targets such as inflation and unemployment rates." [[4](https://www.investopedia.com/terms/g/gdp.asp/)]
#
# Now let's find the right tables and extract the GDP growth for the sub-sharah Africa for the years 2010 - 2014 (last five years according to the dataset).
#
# > Now let's query the `Series` table with a key work `Growth rates` and then selelect the right `SeriesCode` for the GDP growth(annual %)
#
# > The SerierCode we are interested in is `NY.GDP.MKTP.KD.ZG`. We can use this code to query the Indicators table.

# %%
indicator_type_growthRates = pd.read_sql("""
SELECT SeriesCode, IndicatorName, LongDefinition
FROM Series
WHERE Topic LIKE '%Growth rates%';
""", 
                             connect)
indicator_type_growthRates
# Out:
#               SeriesCode                                      IndicatorName  \
# 0      NV.AGR.TOTL.KD.ZG         Agriculture, value added (annual % growth)
# 1      NE.EXP.GNFS.KD.ZG    Exports of goods and services (annual % growth)
# 2      NE.CON.TETC.KD.ZG  Final consumption expenditure, etc. (annual % ...
# 3      NY.GDP.MKTP.KD.ZG                              GDP growth (annual %)
# 4      NY.GDP.PCAP.KD.ZG                   GDP per capita growth (annual %)
# 5      NE.CON.GOVT.KD.ZG  General government final consumption expenditu...
# 6      NE.GDI.TOTL.KD.ZG          Gross capital formation (annual % growth)
# 7      NE.GDI.FTOT.KD.ZG    Gross fixed capital formation (annual % growth)
# 8      NE.CON.PRVT.KD.ZG  Household final consumption expenditure (annua...
# 9   NE.CON.PRVT.PC.KD.ZG  Household final consumption expenditure per ca...
# 10     NE.CON.PETC.KD.ZG  Household final consumption expenditure, etc. ...
# 11     NE.IMP.GNFS.KD.ZG    Imports of goods and services (annual % growth)
# 12     NV.IND.TOTL.KD.ZG            Industry, value added (annual % growth)
# 13     NV.IND.MANF.KD.ZG       Manufacturing, value added (annual % growth)
# 14     NV.SRV.TETC.KD.ZG      Services, etc., value added (annual % growth)
# 15     NY.GNP.MKTP.KD.ZG                              GNI growth (annual %)
# 16     NY.GNP.PCAP.KD.ZG                   GNI per capita growth (annual %)
#
#                                        LongDefinition
# 0   Annual growth rate for agricultural value adde...
# 1   Annual growth rate of exports of goods and ser...
# 2   Average annual growth of final consumption exp...
# 3   Annual percentage growth rate of GDP at market...
# 4   Annual percentage growth rate of GDP per capit...
# 5   Annual percentage growth of general government...
# 6   Annual growth rate of gross capital formation ...
# 7   Average annual growth of gross fixed capital f...
# 8   Annual percentage growth of household final co...
# 9   Annual percentage growth of household final co...
# 10  Annual percentage growth of household final co...
# 11  Annual growth rate of imports of goods and ser...
# 12  Annual growth rate for industrial value added ...
# 13  Annual growth rate for manufacturing value add...
# 14  Annual growth rate for value added in services...
# 15  GNI (formerly GNP) is the sum of value added b...
# 16  Annual percentage growth rate of GNI per capit...

# %%
df_SSA_GDP = pd.read_sql("""

SELECT Year, Value AS GDP, CountryName
FROM Indicators
WHERE CountryName IN 

('Angola',
 'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
 'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
 'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
 'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
 'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
 'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
 'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
 'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND  
 
 IndicatorCode = 'NY.GDP.MKTP.KD.ZG' AND Year IN (2010, 2011, 2012, 2013, 2014) 

 """, connect)

df_SSA_GDP.head(3)
# Out:
#    Year       GDP   CountryName
# 0  2010  2.116850         Benin
# 1  2010  8.563632      Botswana
# 2  2010  8.446325  Burkina Faso

# %% [markdown]
# #### Remark:
# > We know that we have 48 countries for the Sub-Saharan Africa region. However, for various reasons, each contry many not have the data we are interested in. Let's write a function which checks how many of the 48 countries are in the specific query.

# %%
def CountriesWithNoData(df):    
    print('Only {} countries out of the {} have data for our current query.'.format(len(df.CountryName.unique()), len(df_SSA)))
    print('')
    CoutriesWithNoData = [country for country in SSA if country not in df.CountryName.unique()]
    print('Countries with no data in our current query are: ')
    print('')
    for i, country in enumerate(CoutriesWithNoData):
        print(i+1, country)

# %%
CountriesWithNoData(df_SSA_GDP)
# Out:
# Only 41 countries out of the 48 have data for our current query.
#
# Countries with no data in our current query are:
#
# 1 Angola
# 2 Congo
# 3 Côte d'Ivoire
# 4 Dem. Rep. Congo
# 5 São Tomé and Principe
# 6 Somalia
# 7 The Gambia

# %% [markdown]
# Now let's visualize the data. We will be using a plotly bar plot. What we see below is the average GDP growth rate of the countries for the years 2010 to 2014. The yearly breakdown is given in the heatmap that follows.

# %%
df_gdp = df_SSA_GDP.groupby(["CountryName"])['GDP'].mean().sort_values(ascending=True).reset_index()

fig = go.Figure
fig = go.Figure(data=[go.Bar(y=df_gdp['CountryName'], 
                             x=df_gdp['GDP'],
                             orientation='h'
                            ),                     
                     ]
               )

fig.update_layout(title='<b>Annual GDP Growth (%): 2010-2014<b>',
                  yaxis_title='<b>Countries<b>',
                  xaxis_title='<b> GDP Growth (%) <b>',
                  titlefont={'size': 20, 'family':'Serif'},
                  template='simple_white',
                  width=750, height=800,
                )

colors = ['lightseagreen',] * len(df_gdp)
colors[0] = 'crimson' 
colors[1] = 'crimson' 
colors[2] = 'crimson'



fig.update_traces(marker_color=colors, marker_line_color=None,
                  marker_line_width=2.5, opacity=None)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d452a627-c00d-45a3-8a25-47e6d77df034" class="plotly-graph-div" style="height:800px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d452a627-c00d-45a3-8a25-47e6d77df034")) {                    Plotly.newPlot(                        "d452a627-c00d-45a3-8a25-47e6d77df034",                        [{"orientation":"h","x":[-5.745128658382488,-4.915319389342337,-0.5884913391432135,1.137380608210884,2.064863536962373,2.072541131461026,2.28699895581093,2.441844018657024,2.4978177402198103,2.672327900946288,2.8192672886786507,3.49413668541264,3.597299169899788,3.7292907173830345,4.250373231257351,4.628621235827252,4.697326501757209,4.733331426722993,5.006684881430511,5.123688547353263,5.43699507747227,5.444523121739118,5.468167505298878,5.649419627481028,5.742107593161146,5.813223837754785,5.963651355666018,6.01681841227856,6.286342636974163,6.299653824913458,6.637346637080194,6.726520053255891,6.795334696916498,7.073153568039826,7.103109761121341,7.120187699571318,7.2161352447074165,8.435783688215533,8.507329087859386,10.142688105301133,10.647620655467874],"y":["South Sudan","Central African Republic","Equatorial Guinea","Sudan","Madagascar","Cabo Verde","Swaziland","South Africa","Guinea","Comoros","Guinea-Bissau","Mali","Mauritius","Senegal","Burundi","Benin","Cameroon","Malawi","Lesotho","Togo","Eritrea","Mauritania","Uganda","Namibia","Nigeria","Burkina Faso","Seychelles","Kenya","Gabon","Liberia","Botswana","Tanzania","Niger","Mozambique","Chad","Rwanda","Zambia","Zimbabwe","Ghana","Sierra Leone","Ethiopia"],"type":"bar","marker":{"line":{"width":2.5},"color":["crimson","crimson","crimson","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen","lightseagreen"]}}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"] ...

# %%
_ = df_SSA_GDP.pivot(index = 'Year', columns = 'CountryName', values='GDP')

display(_.T.head(10))

fig = px.imshow(_, color_continuous_scale='earth', origin='lower')
fig.update_layout(title='<b> GDP Growth Sub-Saharan Africa: 2010- 2014',
                 template='simple_white',
                 width=850, height=400)
fig.show()
# Out:
# Year                           2010      2011      2012       2013      2014
# CountryName
# Benin                      2.116850  2.962750  4.643023   6.878996  6.541487
# Botswana                   8.563632  6.048316  4.831543   9.322202  4.421041
# Burkina Faso               8.446325  6.521769  6.452675   3.649305  3.996045
# Burundi                    3.785903  4.191626  4.019366   4.594054  4.660918
# Cabo Verde                 1.466913  3.968784  1.081918   1.045244  2.799847
# Cameroon                   3.268649  4.140592  4.588739   5.561688  5.926965
# Central African Republic   3.046657  3.300740  4.112756 -36.047079  1.010329
# Chad                      13.550101  0.082870  8.882576   5.700001  7.300001
# Comoros                    2.200000  2.600000  3.000000   3.500000  2.061639
# Equatorial Guinea         -3.825022  1.939084  5.760499  -6.512923 -0.304095
# <div>                            <div id="32237335-d9df-432a-917a-9e379f345d92" class="plotly-graph-div" style="height:400px; width:850px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32237335-d9df-432a-917a-9e379f345d92")) {                    Plotly.newPlot(                        "32237335-d9df-432a-917a-9e379f345d92",                        [{"coloraxis":"coloraxis","name":"0","x":["Benin","Botswana","Burkina Faso","Burundi","Cabo Verde","Cameroon","Central African Republic","Chad","Comoros","Equatorial Guinea","Eritrea","Ethiopia","Gabon","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritania","Mauritius","Mozambique","Namibia","Niger","Nigeria","Rwanda","Senegal","Seychelles","Sierra Leone","South Africa","South Sudan","Sudan","Swaziland","Tanzania","Togo","Uganda","Zambia","Zimbabwe"],"y":[2010,2011,2012,2013,2014],"z":[[2.11685012701102,8.56363174773267,8.44632518323239,3.78590254312172,1.4669127093504,3.26864887397058,3.04665685156192,13.5501008595489,2.19999998173274,-3.82502188245593,2.19418976921348,12.550538342050901,9.13559174922239,7.899740292681679,1.93621742315426,4.4320216722531,8.402277063702481,7.89114468789391,6.09994469237347,0.263110855703317,6.53336243655625,5.81489176031167,4.77369717040534,4.100201814727701,6.68773184937513,6.0392494098738805,8.369239798490781,7.83973947709083,7.312669274751741,4.17936306191693,5.9454308559869595,5.34664456530697,3.03974708500712,5.49341639529945,3.4693350926497297,1.6808169105211597,6.35888608129918,3.99567877036402,5.1703429744024,10.2982058108767,11.3759212337497],[2.96275035081007,6.04831636706808,6.52176944827904,4.19162568095399,3.9687838117820298,4.14059184658242,3.30073970667341,0.0828697984381961,2.60000008817858,1.9390840675846002,8.67980038573106,11.1782962356071,7.091753340780031,14.046002632334302,3.90876144969184,9.02865559427109,6.11161346041284,4.04854460984166,8.199998145976581,1.4543921677091298,4.34749519278211,2.72358635657149,4.38544119117977,3.8862940347713,7.11760663190503,5.09133819752299,2.31140021999371,4.88738661141304,7.8519349411105,1.76111804930498,7.89470585067909,4.53528431491274,3.21245175505393,-4.6403167360085895,-1.96772897878996,1.3271718061006699,7.90450757234741,4.8837639460034294,9.67322495921286,6.3384461468640705,11.9054078922731],[4.64302307573176,4.83154279471525,6.452674753586071,4.01936552951105,1.0819183107115602,4.58873870051141,4.112756214702601,8.88257607170316,2.99999997193268,5.76049870840316,null,8.647811635390969,5.25107692053524,9.29251186911659,3.9441119888726606,-2.23331753888961,4.55491243845678,4.99362128667759,7.99445127045679,3.02753604385535,1.88579951461693,0.0301253838666184,5.969023853131289,3.2,7.1981858257921205,5.06392417826733,11.8136632751199,4.27927731389333,8.788351534061361,4.363200853150491,6.03978786080307,15.309620774284802,2.2198240062575803,-46.0821223743007,-2.21470319165208,3.02748937734995,5.14101362067316,5.91249111956205,4.41125987205366,6.730573989209889,10.5652042690887],[6.878995974425759,9.32220151646139,3.6493050844558,4.59405421822632,1.04524402260387,5.56168812850224,-36.0470788488193,5.70000136285864,3.4999999938922994,-6.51292304554302,null,10.5822700402272,5.63841404825614,7.31252502101229,2.29999923829236,0.32869042002768395,5.68723131322106,4.46103107099462,8.70387501576046,2.2634995839616296,5.19999998781604,1.70744507644456,5.675564581097929,3.19999999999997,7.14168329950449,5.680297972476339,4.58235529687616,5.394416310894611,4.68451242829828,3.62223201155685,6.6225405548502,20.911790160685,2.2123544313780896,13.1297311406943,3.2999998569541003,2.94914418623138,7.263060030369901,5.1176224559852805,3.27073661317985,6.71345020354607,4.48409514596702],[6.541486651157651,4.4210407594235805,3.99604471922063,4.66091818447367,2.79984680285727,5.9269649 ...

# %% [markdown]
# #### Observations:
# - Ethiopia has the highest overall GDP growth in the years 2010- 2015
# - Siera Leone resgisters the higest GDP growth of 20.9% in the year 2013.
# - South Sudan (2012) and Central African Republic (2013) had the worst GDP loss of 46% and 36% respectively.
# - Eritrea's has not reported GDP values from 2012 - 2014 for some reason.

# %% [markdown]
# ### 2.2 Natural resources
# #### Total natural resources rents (% of GDP)
#
# "This indicator measures total natural resources rents as a share of the gross domestic product (GDP) of a given country. Total natural resources rents are the sum of `oil rents`, `natural gas rents`, `coal rents (hard and soft)`, `mineral rents`, and `forest rents`. Accounting for the contribution of natural resources to economic output is important in building an analytical framework for sustainable development. In some countries earnings from natural resources, especially from fossil fuels and minerals, account for a sizable share of GDP, and much of these earnings come in the form of economic rents - revenues above the cost of extracting the resources. Natural resources give rise to economic rents because they are not produced. For produced goods and services competitive forces expand supply until economic profits are driven to zero, but natural resources in fixed supply often command returns well in excess of their cost of production. Rents from nonrenewable resources - fossil fuels and minerals - as well as rents from overharvesting of forests indicate the liquidation of a country's capital stock. When countries use such rents to support current consumption rather than to invest in new capital to replace what is being used up, they are, in effect, borrowing against their future "[[5](https://landportal.org/taxonomy/term/8165)]
#
# > Similar to the previous query, let's query the `Series` table with a key work `Natural resources contribution to GDP` and then selelect the right `SeriesCode` .
#
# > The SerierCode we are interested in is `NY.GDP.TOTL.RT.ZS`. We can use this code to query the Indicators table.

# %%
indicator_type_naturalResources = pd.read_sql("""
SELECT SeriesCode, IndicatorName, LongDefinition
FROM Series
WHERE Topic LIKE '%Natural resources contribution to GDP%';
""", 
                             connect)
indicator_type_naturalResources
# Out:
#           SeriesCode                             IndicatorName  \
# 0  NY.GDP.COAL.RT.ZS                     Coal rents (% of GDP)
# 1  NY.GDP.FRST.RT.ZS                   Forest rents (% of GDP)
# 2  NY.GDP.MINR.RT.ZS                  Mineral rents (% of GDP)
# 3  NY.GDP.NGAS.RT.ZS              Natural gas rents (% of GDP)
# 4  NY.GDP.PETR.RT.ZS                      Oil rents (% of GDP)
# 5  NY.GDP.TOTL.RT.ZS  Total natural resources rents (% of GDP)
#
#                                       LongDefinition
# 0  Coal rents are the difference between the valu...
# 1  Forest rents are roundwood harvest times the p...
# 2  Mineral rents are the difference between the v...
# 3  Natural gas rents are the difference between t...
# 4  Oil rents are the difference between the value...
# 5  Total natural resources rents are the sum of o...

# %%
for text in enumerate(indicator_type_naturalResources['LongDefinition'].tolist()):
    print(text)
    print('')
# Out:
# (0, 'Coal rents are the difference between the value of both hard and soft coal production at world prices and their total costs of production.')
#
# (1, 'Forest rents are roundwood harvest times the product of average prices and a region-specific rental rate.')
#
# (2, 'Mineral rents are the difference between the value of production for a stock of minerals at world prices and their total costs of production. Minerals included in the calculation are tin, gold, lead, zinc, iron, copper, nickel, silver, bauxite, and phosphate.')
#
# (3, 'Natural gas rents are the difference between the value of natural gas production at world prices and total costs of production.')
#
# (4, 'Oil rents are the difference between the value of crude oil production at world prices and total costs of production.')
#
# (5, 'Total natural resources rents are the sum of oil rents, natural gas rents, coal rents (hard and soft), mineral rents, and forest rents.')

# %%
df_SSA_NatRes = pd.read_sql("""

SELECT Year, Value AS NaturalResource, CountryName
FROM Indicators
WHERE CountryName IN 

('Angola',
 'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
 'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
 'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
 'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
 'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
 'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
 'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
 'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND IndicatorCode = 'NY.GDP.TOTL.RT.ZS' AND Year IN (2010, 2011, 2012, 2013, 2014)
  
 """, connect)

df_SSA_NatRes.head(3)
# Out:
#    Year  NaturalResource CountryName
# 0  2010        45.992915      Angola
# 1  2010         5.068527       Benin
# 2  2010         5.538524    Botswana

# %%
CountriesWithNoData(df_SSA_NatRes)
# Out:
# Only 42 countries out of the 48 have data for our current query.
#
# Countries with no data in our current query are:
#
# 1 Congo
# 2 Côte d'Ivoire
# 3 Dem. Rep. Congo
# 4 São Tomé and Principe
# 5 Somalia
# 6 The Gambia

# %%
x = df_SSA_NatRes.groupby(["CountryName"])['NaturalResource'].mean().index
y = df_SSA_NatRes.groupby(["CountryName"])['NaturalResource'].mean()
fig = go.Figure
fig = go.Figure(data=[go.Bar(x=x, y=y, marker_color='lightseagreen')]).update_xaxes(categoryorder='total descending')

fig.update_layout(title='<b>Total Natural Resources (% GDP) <b>',
                  xaxis_title='<b>Countries<b>',
                  yaxis_title='<b>% GDP<b>',
                  titlefont={'size': 20, 'family':'Serif'},
                  template='simple_white',
                  width=850, height=550,                  
                )

fig.show()
# Out:
# <div>                            <div id="1249ff31-b0e6-4dbb-914f-1581986b67e6" class="plotly-graph-div" style="height:550px; width:850px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1249ff31-b0e6-4dbb-914f-1581986b67e6")) {                    Plotly.newPlot(                        "1249ff31-b0e6-4dbb-914f-1581986b67e6",                        [{"marker":{"color":"lightseagreen"},"x":["Angola","Benin","Botswana","Burkina Faso","Burundi","Cabo Verde","Cameroon","Central African Republic","Chad","Comoros","Equatorial Guinea","Eritrea","Ethiopia","Gabon","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritania","Mauritius","Mozambique","Namibia","Niger","Nigeria","Rwanda","Senegal","Seychelles","Sierra Leone","South Africa","South Sudan","Sudan","Swaziland","Tanzania","Togo","Uganda","Zambia","Zimbabwe"],"y":[41.95363760657645,5.562825593018858,4.4539640588064024,19.971809424222325,26.5106476812158,0.6024898918919644,9.911383523564218,11.052067864135068,31.3929744230323,3.20026951283892,63.21137852177583,17.000081729113088,16.93789669521505,47.50280994953445,17.518585099056924,26.733567407014476,17.0010760783722,3.395230442315,4.966506489335988,30.04494358254065,8.38014296007157,10.52165267199114,15.1914544843384,47.27247507940585,0.004725854746073797,14.47710077387955,2.3215679053887324,15.854314941674076,18.681265192486375,6.6669214919837145,5.01094574541763,0.13509523560756248,9.867751962495317,10.676399070868346,13.827820319583857,11.436319543358584,3.143903326821805,8.780376251064544,9.212339073946348,13.10795509065305,20.670949389495178,12.7428196182945],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"o ...

# %% [markdown]
# #### Observations:
# - Equatorial Guinea's is the highest in the list with around 63% of its GDP coming from natural resources, followed by Gabon and Mauritania.
# - Zooming to the other end of the chart, Mauritius and the other two islands have little to no GDP share coming from the 'natural resources'.
#
# "Mauritius is an African island nation that occupies an area of roughly 790 square miles that is situated within the Indian Ocean. According to the World Bank, the economy of Mauritius had grown significantly since gaining independence in 1968 when it was considered a low-income economy. One of the leading economic experts at the time, Professor James Meade, believed that the nation had very little chance of making significant economic progress. He thought that due to Mauritius' small size, it would be forever trapped in a Malthusian trap which would limit its economic potential. Despite the bleak picture that Professor Meade painted, Mauritius was able to fully utilize the natural resources available to achieve substantial economic growth. `Some of the nation's natural resources include the arable land, the beautiful scenery, and the fish`." [[Ref.7]](https://www.worldatlas.com/articles/what-are-the-major-natural-resources-of-mauritius.html)

# %% [markdown]
# ### 2.3 Health
#
# The data contains many health related topics. For our analysis we have selected only two topics, the countries `total health expenditure`, and the `per capita health expenditures`.
#
# Term defination as per the WDI tables.
#
# **Total health expenditure**: Total health expenditure is the sum of public and private health expenditure. It covers the provision of health services (preventive and curative), family planning activities, nutrition activities, and emergency aid designated for health but does not include provision of water and sanitation.
#
# **Health expenditure per capita (current US$)**: Health expenditure per capita is the sum of public and private health expenditures as a ratio of total population. It covers the provision of health services (preventive and curative), family planning activities, nutrition activities, and emergency aid designated for health but does not include provision of water and sanitation. Data are in current U.S. dollars.
#
# > Now let's query the `Series` table with a key work `Health sevice`.

# %%
indicator_type_health = pd.read_sql("""
SELECT SeriesCode, IndicatorName, LongDefinition
FROM Series
WHERE Topic LIKE '%Health services';
""", 
                             connect)
indicator_type_health
# Out:
#            SeriesCode                                      IndicatorName  \
# 0      SH.MED.CMHW.P3        Community health workers (per 1,000 people)
# 1      SH.XPD.EXTR.ZS  External resources for health (% of total expe...
# 2         SH.XPD.PCAP        Health expenditure per capita (current US$)
# 3   SH.XPD.PCAP.PP.KD  Health expenditure per capita, PPP (constant 2...
# 4      SH.XPD.PRIV.ZS             Health expenditure, private (% of GDP)
# 5      SH.XPD.PUBL.ZS              Health expenditure, public (% of GDP)
# 6   SH.XPD.PUBL.GX.ZS  Health expenditure, public (% of government ex...
# 7         SH.XPD.PUBL  Health expenditure, public (% of total health ...
# 8      SH.XPD.TOTL.ZS               Health expenditure, total (% of GDP)
# 9      SH.MED.BEDS.ZS                   Hospital beds (per 1,000 people)
# 10     SH.MED.NUMW.P3             Nurses and midwives (per 1,000 people)
# 11     SH.XPD.OOPC.ZS  Out-of-pocket health expenditure (% of private...
# 12  SH.XPD.OOPC.TO.ZS  Out-of-pocket health expenditure (% of total e...
# 13     SH.MED.PHYS.ZS                      Physicians (per 1,000 people)
#
#                                        LongDefinition
# 0   Community health workers include various types...
# 1   External resources for health are funds or ser...
# 2   Total health expenditure is the sum of public ...
# 3   Total health expenditure is the sum of public ...
# 4   Private health expenditure includes direct hou...
# 5   Public health expenditure consists of recurren...
# 6   Public health expenditure consists of recurren...
# 7   Public health expenditure consists of recurren...
# 8   Total health expenditure is the sum of public ...
# 9   Hospital beds include inpatient beds available...
# 10  Nurses and midwives include professional nurse...
# 11  Out of pocket expenditure is any direct outlay...
# 12  Out of pocket expenditure is any direct outlay...
# 13  Physicians include generalist and specialist m...

# %%
for text in enumerate(indicator_type_health['IndicatorName'].tolist()):
    print(text)
    print('')
# Out:
# (0, 'Community health workers (per 1,000 people)')
#
# (1, 'External resources for health (% of total expenditure on health)')
#
# (2, 'Health expenditure per capita (current US$)')
#
# (3, 'Health expenditure per capita, PPP (constant 2011 international $)')
#
# (4, 'Health expenditure, private (% of GDP)')
#
# (5, 'Health expenditure, public (% of GDP)')
#
# (6, 'Health expenditure, public (% of government expenditure)')
#
# (7, 'Health expenditure, public (% of total health expenditure)')
#
# (8, 'Health expenditure, total (% of GDP)')
#
# (9, 'Hospital beds (per 1,000 people)')
#
# (10, 'Nurses and midwives (per 1,000 people)')
#
# (11, 'Out-of-pocket health expenditure (% of private expenditure on health)')
#
# (12, 'Out-of-pocket health expenditure (% of total expenditure on health)')
#
# (13, 'Physicians (per 1,000 people)')

# %% [markdown]
# **The two IndicatorCode we are interested in are:**
#
# > `SH.XPD.TOTL.ZS` : Health expenditure, total (% of GDP)
#
# > `SH.XPD.PCAP` : Health expenditure per capita (current US$)

# %%
df_SSA_THE_0 = pd.read_sql("""

SELECT Year, Value AS Total_Health_Expenditure, CountryName
FROM Indicators
WHERE CountryName IN 

('Angola',
 'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
 'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
 'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
 'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
 'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
 'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
 'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
 'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND  
 
 IndicatorCode = 'SH.XPD.TOTL.ZS' AND Year IN (2010, 2011, 2012, 2013, 2014)
 
 """, connect)

df_SSA_THE_1 = pd.read_sql("""

SELECT Year, Value AS Health_Expenditure_perCapita, CountryName
FROM Indicators
WHERE CountryName IN 

('Angola',
 'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
 'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
 'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
 'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
 'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
 'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
 'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
 'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND  
 
 IndicatorCode = 'SH.XPD.PCAP' AND Year IN (2010, 2011, 2012, 2013, 2014)
 
 """, connect)

# %%
# (ref.3) https://stackoverflow.com/questions/44545921/in-pandas-how-to-concatenate-horizontally-and-then-remove-the-redundant-columns

df_SSA_THE = pd.concat([df_SSA_THE_0, df_SSA_THE_1], axis=1).T.drop_duplicates().T
df_SSA_THE.head(3)
# Out:
#    Year Total_Health_Expenditure CountryName Health_Expenditure_perCapita
# 0  2010                 3.408258      Angola                   143.782461
# 1  2010                 4.689867       Benin                    32.343589
# 2  2010                 5.642684    Botswana                   393.879741

# %%
CountriesWithNoData(df_SSA_THE)
# Out:
# Only 41 countries out of the 48 have data for our current query.
#
# Countries with no data in our current query are:
#
# 1 Congo
# 2 Côte d'Ivoire
# 3 Dem. Rep. Congo
# 4 São Tomé and Principe
# 5 Somalia
# 6 The Gambia
# 7 Zimbabwe

# %%
x = df_SSA_THE.groupby(["CountryName"])['Total_Health_Expenditure'].mean().index
y = df_SSA_THE.groupby(["CountryName"])['Total_Health_Expenditure'].mean()

fig = go.Figure
fig = go.Figure(data=[go.Bar(x=x, y=y, marker_color='lightseagreen'),
                      
                     ]
               ).update_xaxes(categoryorder='total descending')

fig.update_layout(title='<b>Total Health Expenditure (% GDP) <b>',
                  xaxis_title='<b>Countries<b>',
                  yaxis_title='<b>Expenditure (% GDP) <b>',
                  titlefont={'size': 20, 'family':'Serif'},
                  template='simple_white',
                  width=850, height=550,
                )

fig.show()
# Out:
# <div>                            <div id="5494f8ba-88d1-4766-9801-4aa32b023996" class="plotly-graph-div" style="height:550px; width:850px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5494f8ba-88d1-4766-9801-4aa32b023996")) {                    Plotly.newPlot(                        "5494f8ba-88d1-4766-9801-4aa32b023996",                        [{"marker":{"color":"lightseagreen"},"x":["Angola","Benin","Botswana","Burkina Faso","Burundi","Cabo Verde","Cameroon","Central African Republic","Chad","Comoros","Equatorial Guinea","Eritrea","Ethiopia","Gabon","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Madagascar","Malawi","Mali","Mauritania","Mauritius","Mozambique","Namibia","Niger","Nigeria","Rwanda","Senegal","Seychelles","Sierra Leone","South Africa","South Sudan","Sudan","Swaziland","Tanzania","Togo","Uganda","Zambia"],"y":[3.5309131775,4.78371704,5.4641678449999995,6.5342177425,8.406359797499999,4.59948668,5.1743097125,3.840510435,3.5913256350000005,5.905188904999999,3.5070055424999995,3.0785971224999997,5.035475975,3.617959425,5.1910753425,4.4882817025,6.16834726,4.394151030000001,11.6079011775,10.757930380000001,4.141956725,8.287944535,6.66099104,3.8331483575,4.9572308275,6.296890425000001,8.0574070125,6.5144889675,3.61900276,11.1759851925,4.4000210475,3.8758343774999995,11.216922275,8.7812821325,2.0574482575,6.5613965425,8.105894764999999,7.29323948,8.1771491925,10.5421935325,4.582266907499999],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.444 ...

# %%
df_h = df_SSA_THE.groupby(["CountryName"])['Health_Expenditure_perCapita'].mean().sort_values(ascending=False).reset_index()

fig = go.Figure
fig = go.Figure(data=[go.Bar(x=df_h['CountryName'] , 
                             y=df_h["Health_Expenditure_perCapita"], 
                             marker_color='crimson'),                      
                     ]
               )

fig.update_layout(title='<b>Health Expenditure Per Capita<b>',
                  xaxis_title='<b>Countries<b>',
                  yaxis_title='<b>Expenditure per Capita (USD) <b>',
                  titlefont={'size': 20, 'family':'Serif'},
                  template='simple_white',
                  width=850, height=550,
                )
fig.show()
# Out:
# <div>                            <div id="806078cb-4690-4221-acd0-c1fb86eb50f8" class="plotly-graph-div" style="height:550px; width:850px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("806078cb-4690-4221-acd0-c1fb86eb50f8")) {                    Plotly.newPlot(                        "806078cb-4690-4221-acd0-c1fb86eb50f8",                        [{"marker":{"color":"crimson"},"x":["Equatorial Guinea","South Africa","Seychelles","Namibia","Mauritius","Botswana","Gabon","Swaziland","Angola","Cabo Verde","Lesotho","Sudan","Nigeria","Ghana","Zambia","Sierra Leone","Rwanda","Cameroon","Uganda","Comoros","Mali","Togo","Senegal","Mauritania","Burkina Faso","Tanzania","Liberia","Kenya","Chad","Benin","Guinea-Bissau","Malawi","Mozambique","South Sudan","Niger","Guinea","Burundi","Ethiopia","Madagascar","Central African Republic","Eritrea"],"y":[710.775951885,632.1931016450001,456.835477275,445.7465091875,443.036218365,399.20317802,395.456760545,263.33519363,194.7673386275,167.08266152000002,131.3065633475,117.17265222749998,95.3783652225,83.24763875,79.3097073725,67.5044985925,65.644688865,62.441388735000004,58.0561728725,50.086478212500005,48.22365422000001,46.980934415,45.91846361,42.754315365000004,42.01853518,41.7351536475,41.614530335,38.9042528475,35.9422928425,35.74964719,34.270045115,32.6814158725,32.571773182499996,26.022156847500003,25.3704060225,20.921500582500002,20.777434095,19.8106291875,18.322829935,16.904361467500003,14.231854134999999],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.333333 ...

# %% [markdown]
# #### Observations:
# - Lesotho, Sierra Leone, Rwanda, Liberia and Uganda are the two five countries that have the highest health expenditure in the SSA region. Around 10-11% of their GDP is dedicated to health expenditure. At 2% South Sudan is at the bottom of the list.
# - However, looking at the per capita expenditure, Equatorial Guinea and South Africa are at the top of the pile with 710 and 632 USD respectively. Eritrea is at the bottom of the list with 14 USD health expenditure per person.
# - About half of the countries spend less than 50 USD per capita on health!

# %% [markdown]
# ### 2.4 Education
#
# "Of all regions, `sub-Saharan Africa` has the highest rates of **education exclusion**. Over one-fifth of children between the ages of about 6 and 11 are out of school, followed by one-third of youth between the ages of about 12 and 14. According to UIS data, almost 60% of youth between the ages of about 15 and 17 are not in school.
#
# "Without urgent action, the situation will likely get worse as the region faces a rising demand for education due to a still-growing school-age population.
#
# "Girls’ education is a major priority. Across the region, 9 million girls between the ages of about 6 and 11 will never go to school at all, compared to 6 million boys, according to UIS data. Their disadvantage starts early: 23% of girls are out of primary school compared to 19% of boys. By the time they become adolescents, the exclusion rate for girls is 36% compared to 32% for boys." [[Ref.]](http://uis.unesco.org/en/topic/education-africa)
#
# > Now let's see what the data says regarding out of school children. We are interested in the boys and girls data.
#
# > For the boys the indicatorCode is `SE.PRM.UNER.MA` and for the girls it is `SE.PRM.UNER.FE`

# %%
indicator_type_education = pd.read_sql("""
SELECT SeriesCode, IndicatorName, LongDefinition
FROM Series
WHERE Topic LIKE '%Education: Participation';
""", 
                             connect)
indicator_type_education
# Out:
#               SeriesCode                                      IndicatorName  \
# 0            SE.PRM.TENR  Adjusted net enrollment rate, primary (% of pr...
# 1         SE.PRM.TENR.FE  Adjusted net enrollment rate, primary, female ...
# 2         SE.PRM.TENR.MA  Adjusted net enrollment rate, primary, male (%...
# 3            SE.PRM.UNER                    Children out of school, primary
# 4         SE.PRM.UNER.FE            Children out of school, primary, female
# 5         SE.PRM.UNER.MA              Children out of school, primary, male
# 6            SE.PRM.ENRL                          Primary education, pupils
# 7      SE.PRM.ENRL.FE.ZS               Primary education, pupils (% female)
# 8            SE.PRE.ENRR            School enrollment, preprimary (% gross)
# 9         SE.PRE.ENRR.FE    School enrollment, preprimary, female (% gross)
# 10        SE.PRE.ENRR.MA      School enrollment, preprimary, male (% gross)
# 11           SE.PRM.ENRR               School enrollment, primary (% gross)
# 12           SE.PRM.NENR                 School enrollment, primary (% net)
# 13     SE.ENR.PRIM.FM.ZS  School enrollment, primary (gross), gender par...
# 14     SE.ENR.PRSC.FM.ZS  School enrollment, primary and secondary (gros...
# 15        SE.PRM.ENRR.FE       School enrollment, primary, female (% gross)
# 16        SE.PRM.NENR.FE         School enrollment, primary, female (% net)
# 17        SE.PRM.ENRR.MA         School enrollment, primary, male (% gross)
# 18        SE.PRM.NENR.MA           School enrollment, primary, male (% net)
# 19        SE.PRM.PRIV.ZS  School enrollment, primary, private (% of tota...
# 20           SE.SEC.ENRR             School enrollment, secondary (% gross)
# 21           SE.SEC.NENR               School enrollment, secondary (% net)
# 22     SE.ENR.SECO.FM.ZS  School enrollment, secondary (gross), gender p...
# 23        SE.SEC.ENRR.FE     School enrollment, secondary, female (% gross)
# 24        SE.SEC.NENR.FE       School enrollment, secondary, female (% net)
# 25        SE.SEC.ENRR.MA       School enrollment, secondary, male (% gross)
# 26        SE.SEC.NENR.MA         School enrollment, secondary, male (% net)
# 27        SE.SEC.PRIV.ZS  School enrollment, secondary, private (% of to...
# 28           SE.TER.ENRR              School enrollment, tertiary (% gross)
# 29     SE.ENR.TERT.FM.ZS  School enrollment, tertiary (gross), gender pa...
# 30        SE.TER.ENRR.FE      School enrollment, tertiary, female (% gross)
# 31        SE.TER.ENRR.MA        School enrollment, tertiary, male (% gross)
# 32        SE.SEC.ENRL.GC                Secondary education, general pupils
# 33  SE.SEC.ENRL.GC.FE.ZS     Secondary education, general pupils (% female)
# 34           SE.SEC.ENRL                        Secondary education, pupils
# 35     SE.SEC.ENRL.FE.ZS             Secondary education, pupils (% female)
# 36        SE.SEC.ENRL.VO             Secondary education, vocational pupils
# 37  SE.SEC.ENRL.VO.FE.ZS  Secondary education, vocational pupils (% female)
#
#                                        LongDefinition
# 0   Adjusted net enrollment is the number of pupil...
# 1   Adjusted net enrollment is the number of pupil...
# 2   Adjusted net enrollment is the number of pupil...
# 3   Children out of school are the number of prima...
# 4   Children out of school are the number of prima...
# 5   Children out of school are the number of prima...
# 6   Primary education pupils is the total number o...
# 7   Female pupils as a percentage of total pupils ...
# 8   Gross enrollment ratio is the ratio of total e...
# 9   Gross enrollment ratio is the ratio of total e...
# 10  Gross enrollment ratio is the ratio of total e...
# 11  Gross enrollment ratio is the ratio of total e...
# 12  Net enrollment rate is the ratio of children o...
# 13  Gender parity index for gross enrollment ratio...
# 14  Gender parity index for gross enrollment ratio...
# 15  Gross enrollment ratio is the ratio of total e...
# 16  Net enrollment rate is the ratio of children o...
# 17  Gross enrollment ratio is the ratio of total e...
# 18  Net enrollment rate is the ratio of children o...
# 19  Private enrollment refers to pupils or student...
# 20  Gross enrollment ratio is the ratio of total e...
# 21  Net enrollment rate is the ratio of children o...
# 22  Gender parity index for gross enrollment ratio...
# 23  Gross enrollment ratio is the ratio of total e...
# 24  Net enrollment rate is the ratio of children o...
# 25  Gross enrollment ratio is the ratio of total e...
# 26  Net enrollment rate is the ratio of children o...
# 27  Private enrollment refers to pupils or student...
# 28  Gross enrollment ratio is the ratio of total e...
# 29  Gender parity index for gross enrollment ratio...
# 30  Gross enrollment ratio is the ratio of total e...
# 31  Gross enrollment ratio is the ratio of total e...
# 32  Secondary general pupils are the number of sec...
# 33  Secondary general pupils are the number of sec...
# 34  Secondary education pupils is the total number...
# 35  Female pupils as a percentage of total pupils ...
# 36  Secondary vocational pupils are the number of ...
# 37  Secondary vocational pupils are the number of ...

# %%
for text in enumerate(indicator_type_education['IndicatorName'].tolist()):
    print(text)
    print('')
# Out:
# (0, 'Adjusted net enrollment rate, primary (% of primary school age children)')
#
# (1, 'Adjusted net enrollment rate, primary, female (% of primary school age children)')
#
# (2, 'Adjusted net enrollment rate, primary, male (% of primary school age children)')
#
# (3, 'Children out of school, primary')
#
# (4, 'Children out of school, primary, female')
#
# (5, 'Children out of school, primary, male')
#
# (6, 'Primary education, pupils')
#
# (7, 'Primary education, pupils (% female)')
#
# (8, 'School enrollment, preprimary (% gross)')
#
# (9, 'School enrollment, preprimary, female (% gross)')
#
# (10, 'School enrollment, preprimary, male (% gross)')
#
# (11, 'School enrollment, primary (% gross)')
#
# (12, 'School enrollment, primary (% net)')
#
# (13, 'School enrollment, primary (gross), gender parity index (GPI)')
#
# (14, 'School enrollment, primary and secondary (gross), gender parity index (GPI)')
#
# (15, 'School enrollment, primary, female (% gross)')
#
# (16, 'School enrollment, primary, female (% net)')
#
# (17, 'School enrollment, primary, male (% gross)')
#
# (18, 'School enrollment, primary, male (% net)')
#
# (19, 'School enrollment, primary, private (% of total primary)')
#
# (20, 'School enrollment, secondary (% gross)')
#
# (21, 'School enrollment, secondary (% net)')
#
# (22, 'School enrollment, secondary (gross), gender parity index (GPI)')
#
# (23, 'School enrollment, secondary, female (% gross)')
#
# (24, 'School enrollment, secondary, female (% net)')
#
# (25, 'School enrollment, secondary, male (% gross)')
#
# (26, 'School enrollment, secondary, male (% net)')
#
# (27, 'School enrollment, secondary, private (% of total secondary)')
#
# (28, 'School enrollment, tertiary (% gross)')
#
# (29, 'School enrollment, tertiary (gross), gender parity index (GPI)')
#
# (30, 'School enrollment, tertiary, female (% gross)')
#
# (31, 'School enrollment, tertiary, male (% gross)')
#
# (32, 'Secondary education, general pupils')
#
# (33, 'Secondary education, general pupils (% female)')
#
# (34, 'Secondary education, pupils')
#
# (35, 'Secondary education, pupils (% female)')
#
# (36, 'Secondary education, vocational pupils')
#
# (37, 'Secondary education, vocational pupils (% female)')

# %%
df_SSA_EDUC_OutSchool_boys = pd.read_sql("""

SELECT Year, Value AS Child_OutOfSchool_Prim_boys, CountryName
FROM Indicators
WHERE CountryName IN 

('Angola',
 'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
 'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
 'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
 'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
 'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
 'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
 'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
 'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND  
 
 IndicatorCode = 'SE.PRM.UNER.MA' AND Year IN (2010, 2011, 2012, 2013, 2014)
  
 """, connect)

df_SSA_EDUC_OutSchool_boys.head(3)
# Out:
#    Year  Child_OutOfSchool_Prim_boys   CountryName
# 0  2010                       119896        Angola
# 1  2010                       492409  Burkina Faso
# 2  2010                        39887       Burundi

# %%
CountriesWithNoData(df_SSA_EDUC_OutSchool_boys)
# Out:
# Only 32 countries out of the 48 have data for our current query.
#
# Countries with no data in our current query are:
#
# 1 Congo
# 2 Côte d'Ivoire
# 3 Dem. Rep. Congo
# 4 Eritrea
# 5 Ethiopia
# 6 Gabon
# 7 Madagascar
# 8 Malawi
# 9 São Tomé and Principe
# 10 Seychelles
# 11 Sierra Leone
# 12 Somalia
# 13 South Africa
# 14 Swaziland
# 15 The Gambia
# 16 Togo

# %%
df_SSA_EDUC_OutOfSchool_girls = pd.read_sql("""

SELECT Year, 
    Value AS Child_OutOfSchool_Prim_girls, 
    CountryName
FROM Indicators
WHERE 
    CountryName IN 
        ('Angola',
         'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
         'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
         'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
         'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
         'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
         'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
         'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
         'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND
     IndicatorCode = 'SE.PRM.UNER.FE' 
 AND 
     Year IN (2010, 2011, 2012, 2013, 2014)
 
 """, connect)

df_SSA_EDUC_OutOfSchool_girls.head(3)
# Out:
#    Year  Child_OutOfSchool_Prim_girls   CountryName
# 0  2010                        376262        Angola
# 1  2010                        540522  Burkina Faso
# 2  2010                         41263       Burundi

# %%
CountriesWithNoData(df_SSA_EDUC_OutOfSchool_girls)
# Out:
# Only 32 countries out of the 48 have data for our current query.
#
# Countries with no data in our current query are:
#
# 1 Congo
# 2 Côte d'Ivoire
# 3 Dem. Rep. Congo
# 4 Eritrea
# 5 Ethiopia
# 6 Gabon
# 7 Madagascar
# 8 Malawi
# 9 São Tomé and Principe
# 10 Seychelles
# 11 Sierra Leone
# 12 Somalia
# 13 South Africa
# 14 Swaziland
# 15 The Gambia
# 16 Togo

# %%
OutOfSchool = pd.concat([df_SSA_EDUC_OutOfSchool_girls, df_SSA_EDUC_OutSchool_boys], axis=1).T.drop_duplicates().T

# %%
xg = OutOfSchool.groupby(["CountryName"])['Child_OutOfSchool_Prim_girls'].mean().index
yg = OutOfSchool.groupby(["CountryName"])['Child_OutOfSchool_Prim_girls'].mean()

xb = OutOfSchool.groupby(["CountryName"])['Child_OutOfSchool_Prim_boys'].mean().index
yb = OutOfSchool.groupby(["CountryName"])['Child_OutOfSchool_Prim_boys'].mean()

fig = go.Figure
fig = go.Figure(data=[go.Bar(x=xg, y=yg, marker_color='salmon', name='girls'),
                      go.Bar(x=xb, y=yb, marker_color='skyblue', name='boys')
                     ]).update_xaxes(categoryorder='total descending')

fig.update_layout(title='<b>Out of School Children, Sub-Saharan Africa (2010 -2014) <b>',
                  xaxis_title='<b>Countries<b>',
                  yaxis_title='<b>Nr. Children<b>',
                  titlefont={'size': 20, 'family':'Serif'},
                  template='simple_white',
                  width=850, height=550,                  
                )

fig.show()
# Out:
# <div>                            <div id="914548c7-efcd-4bfb-b8aa-d722c58404fd" class="plotly-graph-div" style="height:550px; width:850px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("914548c7-efcd-4bfb-b8aa-d722c58404fd")) {                    Plotly.newPlot(                        "914548c7-efcd-4bfb-b8aa-d722c58404fd",                        [{"marker":{"color":"salmon"},"name":"girls","x":["Angola","Benin","Botswana","Burkina Faso","Burundi","Cabo Verde","Cameroon","Central African Republic","Chad","Comoros","Equatorial Guinea","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Mali","Mauritania","Mauritius","Mozambique","Namibia","Niger","Nigeria","Rwanda","Senegal","South Sudan","Sudan","Tanzania","Uganda","Zambia","Zimbabwe"],"y":[415899.0,92509.0,12979.0,491604.5,59490.5,1475.5,198362.0,133615.33333333334,372439.0,10749.0,20244.666666666668,264372.75,266429.75,37137.0,469449.0,30499.0,208252.5,351267.3333333333,74109.25,1100.75,374658.5,20184.0,613625.25,4963815.0,47849.0,205293.25,549760.0,1379030.0,479926.0,311490.0,88158.5,57841.0],"type":"bar"},{"marker":{"color":"skyblue"},"name":"boys","x":["Angola","Benin","Botswana","Burkina Faso","Burundi","Cabo Verde","Cameroon","Central African Republic","Chad","Comoros","Equatorial Guinea","Ghana","Guinea","Guinea-Bissau","Kenya","Lesotho","Liberia","Mali","Mauritania","Mauritius","Mozambique","Namibia","Niger","Nigeria","Rwanda","Senegal","South Sudan","Sudan","Tanzania","Uganda","Zambia","Zimbabwe"],"y":[88639.0,1089.0,15425.0,455934.0,20106.5,713.5,8234.0,67057.33333333333,170995.0,8608.0,20184.333333333332,268102.0,167691.5,32946.0,594181.0,37226.5,209164.5,244591.66666666666,87011.0,1263.0,252806.25,26845.5,472739.0,3745428.0,73130.33333333333,263522.0,442533.0,1372810.5,592909.3333333334,409586.3333333333,102554.25,81353.0],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0 ...

# %% [markdown]
# #### Observations:
# - Generally more girls are out of school than boys which is in agreement with info from UNICEF.
# - The data we have for the time periode we are considering is however spares (around 50% is NaN). Accurate comparision of gender disparity (in terms of children schooling) would improve with more data.

# %%
girls = OutOfSchool.pivot(index = 'Year', columns = 'CountryName', values='Child_OutOfSchool_Prim_girls')
print('GIRLS')
display(girls.T.head(48).style.highlight_null('lightsalmon'))
boys = OutOfSchool.pivot(index = 'Year', columns = 'CountryName', values='Child_OutOfSchool_Prim_boys')
print('BOYS')
display(boys.T.head(48).style.highlight_null('skyblue'))
# Out:
# GIRLS
# <style type="text/css">
# #T_cc472_row0_col2, #T_cc472_row0_col3, #T_cc472_row0_col4, #T_cc472_row1_col0, #T_cc472_row1_col2, #T_cc472_row1_col3, #T_cc472_row1_col4, #T_cc472_row2_col0, #T_cc472_row2_col1, #T_cc472_row2_col3, #T_cc472_row2_col4, #T_cc472_row3_col4, #T_cc472_row4_col1, #T_cc472_row4_col2, #T_cc472_row4_col4, #T_cc472_row5_col4, #T_cc472_row6_col0, #T_cc472_row6_col1, #T_cc472_row6_col3, #T_cc472_row6_col4, #T_cc472_row7_col3, #T_cc472_row7_col4, #T_cc472_row8_col0, #T_cc472_row8_col2, #T_cc472_row8_col4, #T_cc472_row9_col0, #T_cc472_row9_col1, #T_cc472_row9_col2, #T_cc472_row9_col4, #T_cc472_row10_col3, #T_cc472_row10_col4, #T_cc472_row11_col0, #T_cc472_row12_col4, #T_cc472_row13_col1, #T_cc472_row13_col2, #T_cc472_row13_col3, #T_cc472_row13_col4, #T_cc472_row14_col0, #T_cc472_row14_col1, #T_cc472_row14_col3, #T_cc472_row14_col4, #T_cc472_row15_col4, #T_cc472_row16_col0, #T_cc472_row16_col2, #T_cc472_row16_col3, #T_cc472_row17_col3, #T_cc472_row17_col4, #T_cc472_row18_col4, #T_cc472_row19_col4, #T_cc472_row20_col4, #T_cc472_row21_col1, #T_cc472_row21_col3, #T_cc472_row21_col4, #T_cc472_row22_col4, #T_cc472_row23_col1, #T_cc472_row23_col2, #T_cc472_row23_col3, #T_cc472_row23_col4, #T_cc472_row24_col2, #T_cc472_row24_col4, #T_cc472_row25_col3, #T_cc472_row26_col0, #T_cc472_row26_col2, #T_cc472_row26_col3, #T_cc472_row26_col4, #T_cc472_row27_col0, #T_cc472_row27_col3, #T_cc472_row27_col4, #T_cc472_row28_col1, #T_cc472_row28_col4, #T_cc472_row29_col2, #T_cc472_row29_col4, #T_cc472_row30_col4, #T_cc472_row31_col0, #T_cc472_row31_col1, #T_cc472_row31_col3, #T_cc472_row31_col4 {
#   background-color: lightsalmon;
# }
# </style>
# <table id="T_cc472_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="col_heading level0 col0" >2010</th>
#       <th class="col_heading level0 col1" >2011</th>
#       <th class="col_heading level0 col2" >2012</th>
#       <th class="col_heading level0 col3" >2013</th>
#       <th class="col_heading level0 col4" >2014</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CountryName</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc472_level0_row0" class="row_heading level0 row0" >Angola</th>
#       <td id="T_cc472_row0_col0" class="data row0 col0" >376262</td>
#       <td id="T_cc472_row0_col1" class="data row0 col1" >455536</td>
#       <td id="T_cc472_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_cc472_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_cc472_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row1" class="row_heading level0 row1" >Benin</th>
#       <td id="T_cc472_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_cc472_row1_col1" class="data row1 col1" >92509</td>
#       <td id="T_cc472_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_cc472_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_cc472_row1_col4" class="data row1 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row2" class="row_heading level0 row2" >Botswana</th>
#       <td id="T_cc472_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_cc472_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_cc472_row2_col2" class="data row2 col2" >12979</td>
#       <td id="T_cc472_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_cc472_row2_col4" class="data row2 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row3" class="row_heading level0 row3" >Burkina Faso</th>
#       <td id="T_cc472_row3_col0" class="data row3 col0" >540522</td>
#       <td id="T_cc472_row3_col1" class="data row3 col1" >484541</td>
#       <td id="T_cc472_row3_col2" class="data row3 col2" >474376</td>
#       <td id="T_cc472_row3_col3" class="data row3 col3" >466979</td>
#       <td id="T_cc472_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row4" class="row_heading level0 row4" >Burundi</th>
#       <td id="T_cc472_row4_col0" class="data row4 col0" >41263</td>
#       <td id="T_cc472_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_cc472_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_cc472_row4_col3" class="data row4 col3" >77718</td>
#       <td id="T_cc472_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row5" class="row_heading level0 row5" >Cabo Verde</th>
#       <td id="T_cc472_row5_col0" class="data row5 col0" >1962</td>
#       <td id="T_cc472_row5_col1" class="data row5 col1" >1769</td>
#       <td id="T_cc472_row5_col2" class="data row5 col2" >1269</td>
#       <td id="T_cc472_row5_col3" class="data row5 col3" >902</td>
#       <td id="T_cc472_row5_col4" class="data row5 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row6" class="row_heading level0 row6" >Cameroon</th>
#       <td id="T_cc472_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_cc472_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_cc472_row6_col2" class="data row6 col2" >198362</td>
#       <td id="T_cc472_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_cc472_row6_col4" class="data row6 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row7" class="row_heading level0 row7" >Central African Republic</th>
#       <td id="T_cc472_row7_col0" class="data row7 col0" >133868</td>
#       <td id="T_cc472_row7_col1" class="data row7 col1" >139288</td>
#       <td id="T_cc472_row7_col2" class="data row7 col2" >127690</td>
#       <td id="T_cc472_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_cc472_row7_col4" class="data row7 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row8" class="row_heading level0 row8" >Chad</th>
#       <td id="T_cc472_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_cc472_row8_col1" class="data row8 col1" >469460</td>
#       <td id="T_cc472_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_cc472_row8_col3" class="data row8 col3" >275418</td>
#       <td id="T_cc472_row8_col4" class="data row8 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row9" class="row_heading level0 row9" >Comoros</th>
#       <td id="T_cc472_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_cc472_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_cc472_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_cc472_row9_col3" class="data row9 col3" >10749</td>
#       <td id="T_cc472_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row10" class="row_heading level0 row10" >Equatorial Guinea</th>
#       <td id="T_cc472_row10_col0" class="data row10 col0" >21279</td>
#       <td id="T_cc472_row10_col1" class="data row10 col1" >20245</td>
#       <td id="T_cc472_row10_col2" class="data row10 col2" >19210</td>
#       <td id="T_cc472_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_cc472_row10_col4" class="data row10 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row11" class="row_heading level0 row11" >Ghana</th>
#       <td id="T_cc472_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_cc472_row11_col1" class="data row11 col1" >282608</td>
#       <td id="T_cc472_row11_col2" class="data row11 col2" >342260</td>
#       <td id="T_cc472_row11_col3" class="data row11 col3" >225495</td>
#       <td id="T_cc472_row11_col4" class="data row11 col4" >207128</td>
#     </tr>
#     <tr>
#       <th id="T_cc472_level0_row12" class="row_heading level0 row12" >Guinea</th>
#       <td id="T_cc472_row12_col0" class="data row12 col0" >288047</td>
#       <td id="T_cc472_row12_col1" class="data row12 col1" >251967</td>
#       <td id="T_cc472_row12_col2" class="data row12 col2" >263430</td>
#       <td id="T_cc472_row12_col3" class="data row12 col3" >262275</td>
#       <td id="T_cc472
# BOYS
# <style type="text/css">
# #T_09173_row0_col2, #T_09173_row0_col3, #T_09173_row0_col4, #T_09173_row1_col0, #T_09173_row1_col2, #T_09173_row1_col3, #T_09173_row1_col4, #T_09173_row2_col0, #T_09173_row2_col1, #T_09173_row2_col3, #T_09173_row2_col4, #T_09173_row3_col4, #T_09173_row4_col1, #T_09173_row4_col2, #T_09173_row4_col4, #T_09173_row5_col4, #T_09173_row6_col0, #T_09173_row6_col1, #T_09173_row6_col3, #T_09173_row6_col4, #T_09173_row7_col3, #T_09173_row7_col4, #T_09173_row8_col0, #T_09173_row8_col2, #T_09173_row8_col4, #T_09173_row9_col0, #T_09173_row9_col1, #T_09173_row9_col2, #T_09173_row9_col4, #T_09173_row10_col3, #T_09173_row10_col4, #T_09173_row11_col0, #T_09173_row12_col4, #T_09173_row13_col1, #T_09173_row13_col2, #T_09173_row13_col3, #T_09173_row13_col4, #T_09173_row14_col0, #T_09173_row14_col1, #T_09173_row14_col3, #T_09173_row14_col4, #T_09173_row15_col4, #T_09173_row16_col0, #T_09173_row16_col2, #T_09173_row16_col3, #T_09173_row17_col3, #T_09173_row17_col4, #T_09173_row18_col4, #T_09173_row19_col4, #T_09173_row20_col4, #T_09173_row21_col1, #T_09173_row21_col3, #T_09173_row21_col4, #T_09173_row22_col4, #T_09173_row23_col1, #T_09173_row23_col2, #T_09173_row23_col3, #T_09173_row23_col4, #T_09173_row24_col2, #T_09173_row24_col4, #T_09173_row25_col3, #T_09173_row26_col0, #T_09173_row26_col2, #T_09173_row26_col3, #T_09173_row26_col4, #T_09173_row27_col0, #T_09173_row27_col3, #T_09173_row27_col4, #T_09173_row28_col1, #T_09173_row28_col4, #T_09173_row29_col2, #T_09173_row29_col4, #T_09173_row30_col4, #T_09173_row31_col0, #T_09173_row31_col1, #T_09173_row31_col3, #T_09173_row31_col4 {
#   background-color: skyblue;
# }
# </style>
# <table id="T_09173_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="col_heading level0 col0" >2010</th>
#       <th class="col_heading level0 col1" >2011</th>
#       <th class="col_heading level0 col2" >2012</th>
#       <th class="col_heading level0 col3" >2013</th>
#       <th class="col_heading level0 col4" >2014</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >CountryName</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09173_level0_row0" class="row_heading level0 row0" >Angola</th>
#       <td id="T_09173_row0_col0" class="data row0 col0" >119896</td>
#       <td id="T_09173_row0_col1" class="data row0 col1" >57382</td>
#       <td id="T_09173_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_09173_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_09173_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row1" class="row_heading level0 row1" >Benin</th>
#       <td id="T_09173_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_09173_row1_col1" class="data row1 col1" >1089</td>
#       <td id="T_09173_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_09173_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_09173_row1_col4" class="data row1 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row2" class="row_heading level0 row2" >Botswana</th>
#       <td id="T_09173_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_09173_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_09173_row2_col2" class="data row2 col2" >15425</td>
#       <td id="T_09173_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_09173_row2_col4" class="data row2 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row3" class="row_heading level0 row3" >Burkina Faso</th>
#       <td id="T_09173_row3_col0" class="data row3 col0" >492409</td>
#       <td id="T_09173_row3_col1" class="data row3 col1" >443212</td>
#       <td id="T_09173_row3_col2" class="data row3 col2" >442668</td>
#       <td id="T_09173_row3_col3" class="data row3 col3" >445447</td>
#       <td id="T_09173_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row4" class="row_heading level0 row4" >Burundi</th>
#       <td id="T_09173_row4_col0" class="data row4 col0" >39887</td>
#       <td id="T_09173_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_09173_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_09173_row4_col3" class="data row4 col3" >326</td>
#       <td id="T_09173_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row5" class="row_heading level0 row5" >Cabo Verde</th>
#       <td id="T_09173_row5_col0" class="data row5 col0" >1383</td>
#       <td id="T_09173_row5_col1" class="data row5 col1" >938</td>
#       <td id="T_09173_row5_col2" class="data row5 col2" >354</td>
#       <td id="T_09173_row5_col3" class="data row5 col3" >179</td>
#       <td id="T_09173_row5_col4" class="data row5 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row6" class="row_heading level0 row6" >Cameroon</th>
#       <td id="T_09173_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_09173_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_09173_row6_col2" class="data row6 col2" >8234</td>
#       <td id="T_09173_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_09173_row6_col4" class="data row6 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row7" class="row_heading level0 row7" >Central African Republic</th>
#       <td id="T_09173_row7_col0" class="data row7 col0" >62292</td>
#       <td id="T_09173_row7_col1" class="data row7 col1" >72918</td>
#       <td id="T_09173_row7_col2" class="data row7 col2" >65962</td>
#       <td id="T_09173_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_09173_row7_col4" class="data row7 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row8" class="row_heading level0 row8" >Chad</th>
#       <td id="T_09173_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_09173_row8_col1" class="data row8 col1" >300981</td>
#       <td id="T_09173_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_09173_row8_col3" class="data row8 col3" >41009</td>
#       <td id="T_09173_row8_col4" class="data row8 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row9" class="row_heading level0 row9" >Comoros</th>
#       <td id="T_09173_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_09173_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_09173_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_09173_row9_col3" class="data row9 col3" >8608</td>
#       <td id="T_09173_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row10" class="row_heading level0 row10" >Equatorial Guinea</th>
#       <td id="T_09173_row10_col0" class="data row10 col0" >21150</td>
#       <td id="T_09173_row10_col1" class="data row10 col1" >20261</td>
#       <td id="T_09173_row10_col2" class="data row10 col2" >19142</td>
#       <td id="T_09173_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_09173_row10_col4" class="data row10 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row11" class="row_heading level0 row11" >Ghana</th>
#       <td id="T_09173_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_09173_row11_col1" class="data row11 col1" >299628</td>
#       <td id="T_09173_row11_col2" class="data row11 col2" >310258</td>
#       <td id="T_09173_row11_col3" class="data row11 col3" >241046</td>
#       <td id="T_09173_row11_col4" class="data row11 col4" >221476</td>
#     </tr>
#     <tr>
#       <th id="T_09173_level0_row12" class="row_heading level0 row12" >Guinea</th>
#       <td id="T_09173_row12_col0" class="data row12 col0" >182360</td>
#       <td id="T_09173_row12_col1" class="data row12 col1" >159375</td>
#       <td id="T_09173_row12_col2" class="data row12 col2" >167621</td>
#       <td id="T_09173_row12_col3" class="data row12 col3" >161410</td>
#       <td id="T_09173_row12_col4" clas

# %% [markdown]
# ### 2.5 Child Labor
#
# "Nearly 1 in 10 children are subjected to child labour worldwide, with some forced into hazardous work through trafficking."
#
# "Economic hardship exacts a toll on millions of families worldwide – and in some places, it comes at the price of a child’s safety. Roughly 160 million children were subjected to child labour at the beginning of 2020, with 9 million additional children at risk due to the impact of COVID-19.
#
# This accounts for nearly 1 in 10 children worldwide. Almost half of them are in hazardous work that directly endangers their health and moral development.
#
# Children may be driven into work for various reasons. Most often, child labour occurs when families face financial challenges or uncertainty – whether due to poverty, sudden illness of a caregiver, or job loss of a primary wage earner.
#
# The consequences are staggering. Child labour can result in extreme bodily and mental harm, and even death. It can lead to slavery and sexual or economic exploitation. And in nearly every case, it cuts children off from schooling and health care, restricting their fundamental rights and threatening their futures.
#
# Migrant and refugee children – many of whom have been uprooted by conflict, disaster or poverty – also risk being forced into work and even trafficked, especially if they are migrating alone or taking irregular routes with their families.
#
# Trafficked children are often subjected to violence, abuse and other human rights violations. And some may be forced to break the law. For girls, the threat of sexual exploitation looms large, while boys may be exploited by armed forces or groups." [UNICEF (ref.6)](https://www.unicef.org/protection/child-labour)
#
# > Let's now look for the right indicator code and see the data
#
# > We are looking for IndicatorCode for `Children in employment, total (% of children ages 7-14)` , which is `SL.TLF.0714.ZS`

# %%
indicator_type_labour = pd.read_sql("""
SELECT SeriesCode, IndicatorName, LongDefinition
FROM Series
WHERE Topic LIKE '%Social Protection & Labor: Economic activity%';
""", 
                             connect)
indicator_type_labour
# Out:
#               SeriesCode                                      IndicatorName  \
# 0      SL.TLF.0714.SW.TM  Average working hours of children, study and w...
# 1   SL.TLF.0714.SW.FE.TM  Average working hours of children, study and w...
# 2   SL.TLF.0714.SW.MA.TM  Average working hours of children, study and w...
# 3      SL.TLF.0714.WK.TM  Average working hours of children, working onl...
# 4   SL.TLF.0714.WK.FE.TM  Average working hours of children, working onl...
# ..                   ...                                                ...
# 70     SL.EMP.VULN.MA.ZS  Vulnerable employment, male (% of male employm...
# 71        SL.EMP.VULN.ZS  Vulnerable employment, total (% of total emplo...
# 72     SL.EMP.WORK.FE.ZS  Wage and salaried workers, female (% of female...
# 73        SL.EMP.WORK.ZS  Wage and salaried workers, total (% of total e...
# 74     SL.EMP.WORK.MA.ZS  Wage and salary workers, male (% of males empl...
#
#                                        LongDefinition
# 0   Average working hours of children studying and...
# 1   Average working hours of children studying and...
# 2   Average working hours of children studying and...
# 3   Average working hours of children working only...
# 4   Average working hours of children working only...
# ..                                                ...
# 70  Vulnerable employment is unpaid family workers...
# 71  Vulnerable employment is unpaid family workers...
# 72  Wage and salaried workers (employees) are thos...
# 73  Wage and salaried workers (employees) are thos...
# 74  Wage and salaried workers (employees) are thos...
#
# [75 rows x 3 columns]

# %%
for text in enumerate(indicator_type_labour['IndicatorName'].tolist()):
    print(text)
    print('')
# Out:
# (0, 'Average working hours of children, study and work, ages 7-14 (hours per week)')
#
# (1, 'Average working hours of children, study and work, female, ages 7-14 (hours per week)')
#
# (2, 'Average working hours of children, study and work, male, ages 7-14 (hours per week)')
#
# (3, 'Average working hours of children, working only, ages 7-14 (hours per week)')
#
# (4, 'Average working hours of children, working only, female, ages 7-14 (hours per week)')
#
# (5, 'Average working hours of children, working only, male, ages 7-14 (hours per week)')
#
# (6, 'Child employment in agriculture (% of economically active children ages 7-14)')
#
# (7, 'Child employment in agriculture, female (% of female economically active children ages 7-14)')
#
# (8, 'Child employment in agriculture, male (% of male economically active children ages 7-14)')
#
# (9, 'Child employment in manufacturing (% of economically active children ages 7-14)')
#
# (10, 'Child employment in manufacturing, female (% of female economically active children ages 7-14)')
#
# (11, 'Child employment in manufacturing, male (% of male economically active children ages 7-14)')
#
# (12, 'Child employment in services (% of economically active children ages 7-14)')
#
# (13, 'Child employment in services, female (% of female economically active children ages 7-14)')
#
# (14, 'Child employment in services, male (% of male economically active children ages 7-14)')
#
# (15, 'Children in employment, female (% of female children ages 7-14)')
#
# (16, 'Children in employment, male (% of male children ages 7-14)')
#
# (17, 'Children in employment, self-employed (% of children in employment, ages 7-14)')
#
# (18, 'Children in employment, self-employed, female (% of female children in employment, ages 7-14)')
#
# (19, 'Children in employment, self-employed, male (% of male children in employment, ages 7-14)')
#
# (20, 'Children in employment, study and work (% of children in employment, ages 7-14)')
#
# (21, 'Children in employment, study and work, female (% of female children in employment, ages 7-14)')
#
# (22, 'Children in employment, study and work, male (% of male children in employment, ages 7-14)')
#
# (23, 'Children in employment, total (% of children ages 7-14)')
#
# (24, 'Children in employment, unpaid family workers (% of children in employment, ages 7-14)')
#
# (25, 'Children in employment, unpaid family workers, female (% of female children in employment, ages 7-14)')
#
# (26, 'Children in employment, unpaid family workers, male (% of male children in employment, ages 7-14)')
#
# (27, 'Children in employment, wage workers (% of children in employment, ages 7-14)')
#
# (28, 'Children in employment, wage workers, female (% of female children in employment, ages 7-14)')
#
# (29, 'Children in employment, wage workers, male (% of male children in employment, ages 7-14)')
#
# (30, 'Children in employment, work only (% of children in employment, ages 7-14)')
#
# (31, 'Children in employment, work only, female (% of female children in employment, ages 7-14)')
#
# (32, 'Children in employment, work only, male (% of male children in employment, ages 7-14)')
#
# (33, 'Contributing family workers, female (% of females employed)')
#
# (34, 'Contributing family workers, male (% of males employed)')
#
# (35, 'Contributing family workers, total (% of total employed)')
#
# (36, 'Employers, female (% of employment)')
#
# (37, 'Employers, male (% of employment)')
#
# (38, 'Employers, total (% of employment)')
#
# (39, 'Employment in agriculture (% of total employment)')
#
# (40, 'Employment in agriculture, female (% of female employment)')
#
# (41, 'Employment in agriculture, male (% of male employment)')
#
# (42, 'Employment in industry (% of total employment)')
#
# (43, 'Employment in industry, female (% of female employment)')
#
# (44, 'Employment in industry, male (% of male employment)')
#
# (45, 'Employment in services (% of total employment)')
#
# (46, 'Employment in services, female (% of female employment)')
#
# (47, 'Employment in services, male (% of male employment)')
#
# (48, 'Employment to population ratio, 15+, female (%) (modeled ILO estimate)')
#
# (49, 'Employment to population ratio, 15+, female (%) (national estimate)')
#
# (50, 'Employment to population ratio, 15+, male (%) (modeled ILO estimate)')
#
# (51, 'Employment to population ratio, 15+, male (%) (national estimate)')
#
# (52, 'Employment to population ratio, 15+, total (%) (modeled ILO estimate)')
#
# (53, 'Employment to population ratio, 15+, total (%) (national estimate)')
#
# (54, 'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)')
#
# (55, 'Employment to population ratio, ages 15-24, female (%) (national estimate)')
#
# (56, 'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)')
#
# (57, 'Employment to population ratio, ages 15-24, male (%) (national estimate)')
#
# (58, 'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)')
#
# (59, 'Employment to population ratio, ages 15-24, total (%) (national estimate)')
#
# (60, 'GDP per person employed (constant 1990 PPP $)')
#
# (61, 'Part time employment, female (% of total female employment)')
#
# (62, 'Part time employment, female (% of total part time employment)')
#
# (63, 'Part time employment, male (% of total male employment)')
#
# (64, 'Part time employment, total (% of total employment)')
#
# (65, 'Self-employed, female (% of females employed)')
#
# (66, 'Self-employed, male (% of males employed)')
#
# (67, 'Self-employed, total (% of total employed)')
#
# (68, 'Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment)')
#
# (69, 'Vulnerable employment, female (% of female employment)')
#
# (70, 'Vulnerable employment, male (% of male employment)')
#
# (71, 'Vulnerable employment, total (% of total employment)')
#
# (72, 'Wage and salaried workers, female (% of females employed)')
#
# (73, 'Wage and salaried workers, total (% of total employed)')
#
# (74, 'Wage and salary workers, male (% of males employed)')

# %%
df_SSA_labor = pd.read_sql("""

SELECT Year, Value AS Child_empl, CountryName
FROM Indicators
WHERE CountryName IN 

('Angola',
 'Benin','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon',
 'Central African Republic','Chad','Comoros','Congo',"Côte d'Ivoire",
 'Dem. Rep. Congo','Equatorial Guinea','Eritrea','Ethiopia','Gabon',
 'Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Madagascar',
 'Malawi','Mali','Mauritania','Mauritius','Mozambique','Namibia','Niger',
 'Nigeria','Rwanda','São Tomé and Principe','Senegal','Seychelles','Sierra Leone',
 'Somalia','South Africa','South Sudan','Sudan','Swaziland','Tanzania','The Gambia',
 'Togo','Uganda','Zambia','Zimbabwe') 
 
 AND  
 
 IndicatorCode = 'SL.TLF.0714.ZS' AND Year IN (2010, 2011, 2012, 2013, 2014)
 
 """, connect)

df_SSA_labor.head(3)
# Out:
#    Year  Child_empl               CountryName
# 0  2010        50.3              Burkina Faso
# 1  2010        31.9                   Burundi
# 2  2010        37.2  Central African Republic

# %%
CountriesWithNoData(df_SSA_labor)
# Out:
# Only 21 countries out of the 48 have data for our current query.
#
# Countries with no data in our current query are:
#
# 1 Angola
# 2 Botswana
# 3 Cabo Verde
# 4 Comoros
# 5 Congo
# 6 Côte d'Ivoire
# 7 Dem. Rep. Congo
# 8 Equatorial Guinea
# 9 Eritrea
# 10 Ghana
# 11 Guinea-Bissau
# 12 Kenya
# 13 Lesotho
# 14 Madagascar
# 15 Mauritania
# 16 Mauritius
# 17 Mozambique
# 18 Namibia
# 19 São Tomé and Principe
# 20 Seychelles
# 21 Somalia
# 22 South Africa
# 23 South Sudan
# 24 Sudan
# 25 The Gambia
# 26 Zambia
# 27 Zimbabwe

# %%
df_labor = df_SSA_labor.groupby(["CountryName"])['Child_empl'].mean().sort_values(ascending=False).reset_index()


fig = go.Figure(data=[go.Bar(x=df_labor['CountryName'], 
                             y=df_labor['Child_empl'],
                            marker_color='crimson'),                      
                     ]
               )

fig.update_layout(title='<b>Children In Employment, Total (% of children ages 7-14)<b>',
                  xaxis_title='<b>Countries<b>',
                  yaxis_title='<b>Percent (%) of total<b>',
                  titlefont={'size': 20, 'family':'Serif'},
                  template='simple_white',
                  width=900, height=550,
                )
fig.show()
# Out:
# <div>                            <div id="e031d5d9-e7d1-465a-a942-91c79776c440" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e031d5d9-e7d1-465a-a942-91c79776c440")) {                    Plotly.newPlot(                        "e031d5d9-e7d1-465a-a942-91c79776c440",                        [{"marker":{"color":"crimson"},"x":["Cameroon","Burkina Faso","Sierra Leone","Togo","Niger","Guinea","Central African Republic","Uganda","Chad","Burundi","Mali","Tanzania","Ethiopia","Malawi","Benin","Gabon","Nigeria","Rwanda","Liberia","Swaziland","Senegal"],"y":[62.0,50.3,49.55,48.8,48.5,41.5,37.2,36.7,33.1,31.9,29.7,29.4,26.1,25.1,24.1,24.0,21.2,19.1,18.4,13.3,13.1],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outline ...

# %%
fig = px.choropleth(df_SSA_labor, locations="CountryName", locationmode='country names',
                    color="Child_empl",
                    hover_name="CountryName",
                    fitbounds="locations",
                    title = 'Sub-Saharan Africa Child Employment:  2010 - 2014', 
                    width=750, height= 500,
                    template = 'plotly')

fig.update(layout=dict(titlefont={'size': 24, 'family': 'Serif'}))

fig.show()
# Out:
# <div>                            <div id="6486c746-6547-4b6d-b94a-fb3e0f3085a4" class="plotly-graph-div" style="height:500px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6486c746-6547-4b6d-b94a-fb3e0f3085a4")) {                    Plotly.newPlot(                        "6486c746-6547-4b6d-b94a-fb3e0f3085a4",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>CountryName=%{location}<br>Child_empl=%{z}<extra></extra>","hovertext":["Burkina Faso","Burundi","Central African Republic","Chad","Guinea","Liberia","Nigeria","Rwanda","Sierra Leone","Swaziland","Togo","Cameroon","Ethiopia","Malawi","Senegal","Tanzania","Benin","Gabon","Guinea","Niger","Uganda","Mali","Sierra Leone"],"locationmode":"country names","locations":["Burkina Faso","Burundi","Central African Republic","Chad","Guinea","Liberia","Nigeria","Rwanda","Sierra Leone","Swaziland","Togo","Cameroon","Ethiopia","Malawi","Senegal","Tanzania","Benin","Gabon","Guinea","Niger","Uganda","Mali","Sierra Leone"],"name":"","z":[50.3,31.9,37.2,33.1,44.9,18.4,21.2,19.1,39.9,13.3,48.8,62.0,26.1,25.1,13.1,29.4,24.1,24.0,38.1,48.5,36.7,29.7,59.2],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"t ...

# %% [markdown]
# #### Observations:
# - We note that all countries do not appear on the list, only 21 out of the 48 counties have data for this query.
# - Cameroon at 62% is the highest child labour exploiter.

# %% [markdown]
# ### End Note:
#
# As stated from the outset, the main objective of this notebook was to practice SQL. To that end this notebook serves as a *first* (only basic queries were covered) learning step in the world of SQL and querying data bases. Along the way I have also tried to look at and visualize some of the socio-economic data of the Sub-Saharan Africa region for years 2010 - 2014.

# %% [markdown]
# ### References:
#
# [1]. https://www.kaggle.com/code/jonaspalucibarbosa/wdi-brazil-unemployment-using-sql-for-analysis
#
# [2]. https://www.geeksforgeeks.org/how-to-list-tables-using-sqlite3-in-python/
#
# [3]. https://stackoverflow.com/questions/44545921/in-pandas-how-to-concatenate-horizontally-and-then-remove-the-redundant-columns
#
# [4]. https://www.investopedia.com/terms/g/gdp.
#
# [5]. https://landportal.org/taxonomy/term/8165
#
# [6]. https://www.unicef.org/protection/child-labour
#
# [7]. https://www.worldatlas.com/articles/what-are-the-major-natural-resources-of-mauritius.html
#
# [8]. https://mode.com/sql-tutorial/introduction-to-sql/

# %% [markdown]
# ---
# ##### Check list (SQL Basics) according to ref. 8:
#
# - SELECT
# - LIMIT
# - WHERE
# - Comparison Operators
# - Logical Operators
# - LIKE
# - IN
# - BETWEEN
# - IS NULL
# - AND
# - OR
# - NOT
# - ORDER BY
#
# ---
